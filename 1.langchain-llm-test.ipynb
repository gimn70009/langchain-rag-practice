# %% [markdown]
# # 1. 환경변수 불러오기

# %%
from dotenv import load_dotenv

# env 파일을 찾아서 불러옴
load_dotenv()
# Out:
# True

# %% [markdown]
# # 2. OpenAI LLM 초기화

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI()

# %%
ai_message = llm.invoke("안녕하세요")

# %%
ai_message.content
# Out:
# '안녕하세요! 무엇을 도와드릴까요?'
